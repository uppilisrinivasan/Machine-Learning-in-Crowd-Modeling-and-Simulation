# %% [markdown]
# # Task 1 Vector fields, orbits, and visualization

# %%
import numpy as np
from task1 import *

# %%
alpha = 0.1
A = np.array([
    [alpha, alpha],
    [-1/4, 0]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [0.05+0.15j 0.05-0.15j]
# Shape of UV Matrix is: (2, 10000)

# %%
alpha = -0.3
A = np.array([
    [alpha, alpha],
    [-1/4, 0]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [-0.4622499  0.1622499]
# Shape of UV Matrix is: (2, 10000)

# %%
alpha = 1
A = np.array([
    [alpha, alpha],
    [-1/4, 0]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [0.5 0.5]
# Shape of UV Matrix is: (2, 10000)

# %%
alpha = -0.3
A = np.array([
    [alpha, 0],
    [0, -1]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [-0.3 -1. ]
# Shape of UV Matrix is: (2, 10000)

# %%
alpha = 0.3
A = np.array([
    [-alpha, alpha],
    [-1/4, 0]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [-0.15+0.22912878j -0.15-0.22912878j]
# Shape of UV Matrix is: (2, 10000)

# %%
alpha = -0.3
A = np.array([
    [-alpha, alpha],
    [-1/4, 0]
])
plot_phase_portrait(A, alpha)
# Out:
# Eigenvalues of A:  [ 0.4622499 -0.1622499]
# Shape of UV Matrix is: (2, 10000)
