# %% [markdown]
# # Task 2: Common bifurcations in nonlinear systems

# %%
import numpy as np
from task2 import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
alpha = np.linspace(-1, 5,num=150)
#print(alpha)

# %%
bifurcation_plot(equation, alpha, one =True)

# %%
alpha = np.linspace(-10, 10,num=100)

# %%
bifurcation_plot(equation, alpha, one = False)
