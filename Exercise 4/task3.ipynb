# %% [markdown]
# # Task 3: Bifurcations in higher dimensions

# %%
from task3 import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Task 3.1

# %% [markdown]
# Plot different phase diagrams(with different values for alpha) of the following system:
#
# Andronov-Hopf bifurcation:
#
# $$\dot x_1 = \alpha x_1 - x_2 - x_1(x_1^2 + x_2^2)$$
# $$\dot x_2 = x_1 + \alpha x_2 - x_2(x_1^2 + x_2^2)$$

# %%
alphas = [-2,-1,0,1,2]

for alpha in alphas:
    phase_portrait_andronov_hopf(alpha)

# %% [markdown]
# # Task 3.2

# %% [markdown]
# Numerically compute and visualize two orbits of the system forward in time, starting at the point (2; 0) and at (0:5; 0). Here the alpha is set to be equal to 1

# %%
orbits = ([2,0],[0.5,0])
for orbit in orbits:
    plot_orbit(orbit)

# %% [markdown]
# # Task 3.3

# %% [markdown]
# Visualize the bifurcation surface of the CUSP BIFURCATION in a 3D plot,
#
# $$\dot x = \alpha_1 + \alpha_2 x - x^3$$

# %%
plot_surface_cusp()
