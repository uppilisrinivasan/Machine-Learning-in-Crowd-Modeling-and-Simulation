# %% [markdown]
# # Task 4
# ## Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from helper_functions import *

# %% [markdown]
# ## Plotting closed 1D manifold

# %%
data = np.genfromtxt('takens_1.txt')
print(data)
plt.plot(data[:,0],data[:,1])
# Out:
# [[ 2.16837096 -0.54631259]
#  [ 2.17981061 -0.53247518]
#  [ 2.19002807 -0.51894034]
#  ...
#  [ 2.14086777 -0.5761134 ]
#  [ 2.15555144 -0.56069056]
#  [ 2.16853679 -0.54611965]]

# %% [markdown]
# ## Plotting first coordinate w.r.t time
# ### Data is plotted with all given points without delay

# %%
time = [i for i in range(data.shape[0])]
t_plot = np.array(time)
p = -1
for ii in range(data.shape[0]-1):
    if abs(data[ii+1,0]-data[0,0]) < 0.001:
        p = ii;
        break
print("The period = ")
print(p)
plt.plot(t_plot,data[:,0])
# Out:
# The period =
# 332

# %% [markdown]
# ## Plotting delayed dataset
# ### (Only every 10th entry is taken into account)

# %%
data_delay_10 = data[:,0][10:1000]
data_delay_20 = data[:,0][20:1000]
data_delay_50 = data[:,0][50:1000]
data_delay_70 = data[:,0][70:1000]
data_delay_80 = data[:,0][80:1000]
data_delay_90 = data[:,0][90:1000]
data_delay_100 = data[:,0][100:1000]
data_delay_110 = data[:,0][110:1000]
data_delay_120 = data[:,0][120:1000]
data_delay_130 = data[:,0][130:1000]
data_delay_140 = data[:,0][140:1000]
data_delay_150 = data[:,0][150:1000]
data_delay_160 = data[:,0][160:1000]
data_delay_170 = data[:,0][170:1000]
data_delay_180 = data[:,0][180:1000]
data_delay_190 = data[:,0][190:1000]
data_delay_200 = data[:,0][200:1000]
data_delay_220 = data[:,0][220:1000]
data_delay_240 = data[:,0][240:1000]
data_delay_300 = data[:,0][300:1000]

# %%
plt.plot(data[:,0][0:990],data_delay_10)

# %%
plt.plot(data[:,0][0:980],data_delay_20)

# %%
plt.plot(data[:,0][0:950],data_delay_50)

# %%
plt.plot(data[:,0][0:930],data_delay_70)

# %%
plt.plot(data[:,0][0:920],data_delay_80)

# %%
plt.plot(data[:,0][0:910],data_delay_90)

# %%
plt.plot(data[:,0][0:900],data_delay_100)

# %%
plt.plot(data[:,0][0:890],data_delay_110)

# %%
plt.plot(data[:,0][0:880],data_delay_120)

# %%
plt.plot(data[:,0][0:870],data_delay_130)

# %%
plt.plot(data[:,0][0:860],data_delay_140)

# %%
plt.plot(data[:,0][0:850],data_delay_150)

# %%
plt.plot(data[:,0][0:840],data_delay_160)

# %%
plt.plot(data[:,0][0:830],data_delay_170)

# %%
plt.plot(data[:,0][0:820],data_delay_180)

# %%
plt.plot(data[:,0][0:810],data_delay_190)

# %%
plt.plot(data[:,0][0:800],data_delay_200)

# %%
plt.plot(data[:,0][0:780],data_delay_220)

# %%
plt.plot(data[:,0][0:760],data_delay_240)

# %%
plt.plot(data[:,0][0:700],data_delay_300)

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_1 = data[:,0][0:980]
y_1 = data_delay_10[0:980]
z_1 = data_delay_20

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_1, y_1, z_1)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")

#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_1, label='x(t)')
plt.plot(y_1, label='x(t+$\Delta t)$')
plt.plot(z_1, label='x(t+2$\Delta t)$')
plt.legend()

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_2 = data[:,0][0:900]
y_2 = data_delay_50[0:900]
z_2 = data_delay_100

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_2, y_2, z_2)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")


#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_2, label='x(t)')
plt.plot(y_2, label='x(t+$\Delta t)$')
plt.plot(z_2, label='x(t+2$\Delta t)$')
plt.legend()

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_3 = data[:,0][0:800]
y_3 = data_delay_100[0:800]
z_3 = data_delay_200

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_3, y_3, z_3)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")


#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_3, label='x(t)')
plt.plot(y_3, label='x(t+$\Delta t)$')
plt.plot(z_3, label='x(t+2$\Delta t)$')
plt.legend()

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_4 = data[:,0][0:780]
y_4 = data_delay_110[0:780]
z_4 = data_delay_220

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_4, y_4, z_4)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")


#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_4, label='x(t)')
plt.plot(y_4, label='x(t+$\Delta t)$')
plt.plot(z_4, label='x(t+2$\Delta t)$')
plt.legend()

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_5 = data[:,0][0:760]
y_5 = data_delay_120[0:760]
z_5 = data_delay_240

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_5, y_5, z_5)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")

for angle in range(0, 360):
   ax.view_init(30, angle)

#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_5, label='x(t)')
plt.plot(y_5, label='x(t+$\Delta t)$')
plt.plot(z_5, label='x(t+2$\Delta t)$')
plt.legend()

# %%
# Assigning values of time delay embedding to x, y and z coordinates
x_10 = data[:,0][0:700]
y_10 = data_delay_150[0:700]
z_10 = data_delay_300

# %%
# Plot the time delayed embedded manifold in three dimensions
fig = plt.figure(figsize=(8, 4.5))
ax = fig.add_subplot(projection='3d')

sc = ax.scatter(x_10, y_10, z_10)#, c=t,cmap='Blues')
    
#ax.scatter(x,y,z,c=t,cmap='coolwarm')
ax.set_xlabel('X(t)')
ax.set_ylabel('X(t+$\Delta t$)')
ax.set_zlabel('X(t+2$\Delta t$)')
ax.set_title("Time delay embedding")

for angle in range(0, 360):
   ax.view_init(40, angle)

#plt.colorbar(sc)

plt.figure(figsize=(8,4.5))
plt.plot(x_10, label='x(t)')
plt.plot(y_10, label='x(t+$\Delta t)$')
plt.plot(z_10, label='x(t+2$\Delta t)$')
plt.legend()
